# %%
import numpy as np
import os
from glob import glob
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

base_skin_dir = os.path.join('', 'input')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-20-4b711fb9bf91> in <module>
#       5 import matplotlib.pyplot as plt
#       6 from sklearn.model_selection import train_test_split
# ----> 7 import keras
#       8 from keras.utils.np_utils import to_categorical
#       9
#
# ModuleNotFoundError: No module named 'keras'

# %%
imageid_path_dict = {os.path.splitext(os.path.basename(x))[0]: x for x in glob(os.path.join(base_skin_dir, '*', '*.jpg'))}

lesion_type_dict = {
    'nv': 'Melanocytic nevi',
    'mel': 'dermatofibroma',
    'bkl': 'Benign keratosis-like lesions ',
    'bcc': 'Basal cell carcinoma',
    'akiec': 'Actinic keratoses',
    'vasc': 'Vascular lesions',
    'df': 'Dermatofibroma'
}

tile_df = pd.read_csv(os.path.join(base_skin_dir, 'HAM10000_metadata.csv'))
tile_df['path'] = tile_df['image_id'].map(imageid_path_dict.get)
tile_df['cell_type'] = tile_df['dx'].map(lesion_type_dict.get) 
tile_df['cell_type_idx'] = pd.Categorical(tile_df['cell_type']).codes
tile_df.sample(3)
# Out:
#         lesion_id      image_id   dx    dx_type   age     sex  \
# 9036  HAM_0004443  ISIC_0031473   nv      histo  75.0    male
# 4347  HAM_0001653  ISIC_0027895   nv  follow_up  55.0  female
# 1564  HAM_0003679  ISIC_0032840  mel      histo  55.0    male
#
#          localization                                           path  \
# 9036             face  input/HAM10000_images_part_2/ISIC_0031473.jpg
# 4347  lower extremity  input/HAM10000_images_part_1/ISIC_0027895.jpg
# 1564  lower extremity  input/HAM10000_images_part_2/ISIC_0032840.jpg
#
#              cell_type  cell_type_idx
# 9036  Melanocytic nevi              4
# 4347  Melanocytic nevi              4
# 1564    dermatofibroma              6

# %%
tile_df.describe(exclude=[np.number])
# Out:
#           lesion_id      image_id     dx dx_type    sex localization  \
# count         10015         10015  10015   10015  10015        10015
# unique         7470         10015      7       4      3           15
# top     HAM_0005263  ISIC_0029090     nv   histo   male         back
# freq              6             1   6705    5340   5406         2192
#
#                                                  path         cell_type
# count                                           10015             10015
# unique                                          10015                 7
# top     input/HAM10000_images_part_1/ISIC_0027855.jpg  Melanocytic nevi
# freq                                                1              6705

# %%
fig, ax1 = plt.subplots(1, 1, figsize = (10, 5))
tile_df['cell_type'].value_counts().plot(kind='bar', ax=ax1)

# %%
# load in all of the images
from skimage.io import imread
tile_df['image'] = tile_df['path'].map(imread)
#tile_df['image'].map(lambda x: x.shape).value_counts()

# %%
n_samples = 5
fig, m_axs = plt.subplots(7, n_samples, figsize = (4*n_samples, 3*7))
for n_axs, (type_name, type_rows) in zip(m_axs, 
                                         tile_df.sort_values(['cell_type']).groupby('cell_type')):
    n_axs[0].set_title(type_name)
    for c_ax, (_, c_row) in zip(n_axs, type_rows.sample(n_samples, random_state=2018).iterrows()):
        c_ax.imshow(c_row['image'])
        c_ax.axis('off')
fig.savefig('category_samples.png', dpi=300)

# %%
features=tile_df.drop(columns=['cell_type_idx'],axis=1)
target=tile_df['cell_type_idx']
x_train_o, x_test_o, y_train_o, y_test_o = train_test_split(features, target, test_size=0.20,random_state=1234)

# %%
print(y_train_o)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-2c6afe2998eb> in <module>
#       1 # Perform one-hot encoding on the labels
# ----> 2 y_train = to_categorical(y_train_o, num_classes = 7)
#       3 y_test = to_categorical(y_test_o, num_classes = 7)
#       4
#       5 print(y_train)
#
# NameError: name 'to_categorical' is not defined
